# %% [markdown]
# ## Use barcharts and heatmaps to visualize patterns in your data
#
# Created by Huu Hung Nguyen (ID: 017051866)
#
# Last updated: Nov 26, 2024
#
# Learning outcomes: Creating a matrix plot in seaborn using the heatmap() function for IGN Game Reviews that provide scores from experts for the most recent game releases, ranging from 0 (Disaster) to 10 (Masterpiece).
#
# <img src="https://i.imgur.com/Oh06Fu1.png">

# %% [markdown]
# ## Load the data
# 1. Read the IGN data file into a dataframe named `ign_scores`.
# 2. Use the `"Platform"` column to label the rows.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

IGN="https://raw.githubusercontent.com/csbfx/advpy122-data/master/ign_scores.csv"
ign_scores = pd.read_csv(IGN, index_col="Platform")
ign_scores.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# Game Boy Advance    6.928571  6.694444  7.175000
# Game Boy Color      5.900000  5.790698  7.400000
# GameCube            8.028571  7.481319  7.116667
# Nintendo 3DS        7.700000  6.388889  7.900000

# %%
ign_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, Dreamcast to iPhone
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Action             21 non-null     float64
#  1   Action, Adventure  21 non-null     float64
#  2   Adventure          21 non-null     float64
#  3   Fighting           21 non-null     float64
#  4   Platformer         21 non-null     float64
#  5   Puzzle             21 non-null     float64
#  6   RPG                21 non-null     float64
#  7   Racing             21 non-null     float64
#  8   Shooter            21 non-null     float64
#  9   Simulation         21 non-null     float64
#  10  Sports             21 non-null     float64
#  11  Strategy           21 non-null     float64
# dtypes: float64(12)
# memory usage: 2.1+ KB

# %%
ign_scores.isnull().sum()
# Out:
# Action               0
# Action, Adventure    0
# Adventure            0
# Fighting             0
# Platformer           0
# Puzzle               0
# RPG                  0
# Racing               0
# Shooter              0
# Simulation           0
# Sports               0
# Strategy             0
# dtype: int64

# %% [markdown]
# ## Problem 1 - (1 point)
# Use the dataframe ign_scores and write one line of code to determine the highest score received by any kind of games on the Wii platform?

# %%
ign_scores.loc["Wii"].max()
# Out:
# 7.410344827586206

# %% [markdown]
# ## Problem 2 - (1 point)
# Use the dataframe `ign_scores` to determine which genre has the lowest score for the `PlayStation Vita` platform.

# %%
ign_scores.loc["PlayStation Vita"].idxmin()
# Out:
# 'Simulation'

# %% [markdown]
# ## Problem 3 -  (2 points)
# Your instructor's favorite video game has been Mario Kart Wii, a racing game released for the Wii platform in 2008. And, IGN agrees with her that it is a great game -- their rating for this game is a whopping 8.9! Inspired by the success of this game, your instructor is considering creating your very own racing game for the Wii platform. Perform the following analyses to help her determine which platform she should focus on.
#
# 1. Create a bar chart that shows the score for *Racing* games, for each platform. Your chart should have one bar for each platform. Provide a meaningful title to the plot.
#
# 2. Based on the bar chart, do you expect a racing game for the **Wii** platform to receive a high rating?  If not, use the pandas to find out from the dataframe `ign_scores` which gaming platform is the best for racing game?

# %%
# (1 point)
# Set the width and height of the figure
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x=ign_scores.index, y=ign_scores['Racing'])
plt.xlabel("Platform")
plt.ylabel("Score")
plt.title("Racing Game Scores Across Platforms")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the bar chart, the racing game for the Wii platform doesn't receive a high rating.

# %%
## (1 point)
## Use ign_scores to determine which gaming platform is the best
## for racing game.
best_platform_racing = ign_scores["Racing"].idxmax()
print(f"Best platform for racing games: {best_platform_racing}")
# Out:
# Best platform for racing games: Xbox One

# %% [markdown]
# #### Problem 4 - (2 points)
# Since your instructor's gaming interests are pretty broad, you can help her decide to use the IGN scores to determine the choice of genre and platform.
#
# 1. Create a heatmap using the IGN scores by genre and platform and include the scores in the cells of the heatmap.
# 2. Base on the heatmap, which combination of genre and platform receives the highest average ratings?  Which combination receives the lowest average rankings? Write the answers in a markdown cell.

# %%
# prompt: Create a heatmap using the IGN scores by genre and platform and include the scores in the cells of the heatmap.
# Base on the heatmap, which combination of genre and platform receives the highest average ratings? Which combination receives the lowest average rankings? Write the answers in a markdown cell.

# 1. Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(ign_scores, annot=True, cmap='viridis')
plt.title('IGN Scores by Genre and Platform')
plt.xlabel('Genre')
plt.ylabel('Platform')
plt.show()

# 2. Interpretation in markdown cell
# Based on the heatmap:
# Highest average rating:  Xbox 360 and Shooter
# Lowest average ranking:  Gamecube and Platform

# %%
# Create a heatmap
plt.figure(figsize=(13, 11))
sns.heatmap(ign_scores, annot=True, cmap="YlGnBu")
plt.title("IGN Scores by Genre and Platform")
plt.xlabel("Genre")
plt.ylabel("Platform")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Find the highest and lowest average rating combinations
highest_rating = ign_scores.stack().idxmax()
lowest_rating = ign_scores.stack().idxmin()
print(f"Highest rating: {highest_rating}")
print(f"Lowest rating: {lowest_rating}")
# Out:
# Highest rating: ('PlayStation 4', 'Simulation')
# Lowest rating: ('Game Boy Color', 'Fighting')

# %% [markdown]
# Base on the heatmap,
# - the combination of genre and platform receives the highest average ratings is `Simulation` and `PlayStation 4`.
# - the combination of genre and platform receives the lowest average rankings
# is `Fighting` and `Game Boy Color` or `Shooter` and `Game Boy Color`

# %% [markdown]
# ## Problem 5 - (4 points)
# Use the Pokemon dataset to create a clustermap with color. First, filter the dataframe to only keep data with `Type 1` equals to following values: `Water`, `Normal`, `Grass`, `Bug` and `Psychic`. Annotate the dendrogram using different colors for these five different `Type 1` values. Use `Name` as the index.
#
# pokemon_data is in https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv

# %%
# Problem 5
# Load Pokemon data
pokemon_df = pd.read_csv("https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv")

# Filter data for specific Type 1 values
filtered_df = pokemon_df[pokemon_df["Type 1"].isin(["Water", "Normal", "Grass", "Bug", "Psychic"])]

# Set index to Name
filtered_df.set_index("Name", inplace=True)

# Create clustermap
clustermap = sns.clustermap(filtered_df.select_dtypes(include='number'),
                            cmap="viridis",
                            method="ward",
                            metric="euclidean",
                            row_colors=filtered_df['Type 1'].map({
                                'Water': 'blue',
                                'Normal': 'grey',
                                'Grass': 'green',
                                'Bug': 'orange',
                                'Psychic': 'purple'
                            }),
                            figsize=(12, 8))

# Add title
clustermap.fig.suptitle("Clustermap of Selected Pokemon Types", y=1.02)
plt.show()
